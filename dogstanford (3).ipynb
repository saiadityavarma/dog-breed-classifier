# %%
# !wget http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar
# Out:
# --2019-04-24 03:47:44--  http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar
# Resolving vision.stanford.edu (vision.stanford.edu)... 171.64.68.10
# Connecting to vision.stanford.edu (vision.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 793579520 (757M) [application/x-tar]
# Saving to: ‘images.tar’
#
# images.tar          100%[===================>] 756.82M  10.3MB/s    in 64s
#
# 2019-04-24 03:48:48 (11.9 MB/s) - ‘images.tar’ saved [793579520/793579520]

# %%
# !apt-get install p7zip-full
# !p7zip -d images.tar.7z
# !tar -xvf images.tar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# /usr/bin/p7zip: cannot read images.tar.7z
# Images/
# Images/n02085620-Chihuahua/
# Images/n02085620-Chihuahua/n02085620_10621.jpg
# Images/n02085620-Chihuahua/n02085620_10976.jpg
# Images/n02085620-Chihuahua/n02085620_11238.jpg
# Images/n02085620-Chihuahua/n02085620_11258.jpg
# Images/n02085620-Chihuahua/n02085620_11337.jpg
# Images/n02085620-Chihuahua/n02085620_1152.jpg
# Images/n02085620-Chihuahua/n02085620_11696.jpg
# Images/n02085620-Chihuahua/n02085620_11818.jpg
# Images/n02085620-Chihuahua/n02085620_11948.jpg
# Images/n02085620-Chihuahua/n02085620_1205.jpg
# Images/n02085620-Chihuahua/n02085620_12334.jpg
# ...

# %%
import os
os.makedirs('train')
os.makedirs('test')
os.makedirs('validation')

# %%
os.makedirs('weights')

# %%
dirlist=os.listdir('Images')

# %%
for i in dirlist:
  os.makedirs('test/'+i)
  os.makedirs('validation/'+i)  
  os.makedirs('train/'+i)

# %%
for i in dirlist:
  length=round(0.5*len(os.listdir('Images/'+i)))
  pathi='Images'
  # !find 'Images/$i' -type f -name "*.jpg" -print0 | xargs -0 shuf -e -n $length -z | xargs -0 mv -vt 'train/$i'
# Out:
# renamed 'Images/n02108089-boxer/n02108089_4042.jpg' -> 'train/n02108089-boxer/n02108089_4042.jpg'
# renamed 'Images/n02108089-boxer/n02108089_13839.jpg' -> 'train/n02108089-boxer/n02108089_13839.jpg'
# renamed 'Images/n02108089-boxer/n02108089_2355.jpg' -> 'train/n02108089-boxer/n02108089_2355.jpg'
# renamed 'Images/n02108089-boxer/n02108089_2526.jpg' -> 'train/n02108089-boxer/n02108089_2526.jpg'
# renamed 'Images/n02108089-boxer/n02108089_268.jpg' -> 'train/n02108089-boxer/n02108089_268.jpg'
# renamed 'Images/n02108089-boxer/n02108089_3669.jpg' -> 'train/n02108089-boxer/n02108089_3669.jpg'
# renamed 'Images/n02108089-boxer/n02108089_10774.jpg' -> 'train/n02108089-boxer/n02108089_10774.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1003.jpg' -> 'train/n02108089-boxer/n02108089_1003.jpg'
# renamed 'Images/n02108089-boxer/n02108089_2670.jpg' -> 'train/n02108089-boxer/n02108089_2670.jpg'
# ...

# %%
for i in dirlist:
  length=round(0.1*len(os.listdir('Images/'+i)))
  pathi='Images'
  # !find 'Images/$i' -type f -name "*.jpg" -print0 | xargs -0 shuf -e -n $length -z | xargs -0 mv -vt 'test/$i'
# Out:
# renamed 'Images/n02108089-boxer/n02108089_4681.jpg' -> 'test/n02108089-boxer/n02108089_4681.jpg'
# renamed 'Images/n02108089-boxer/n02108089_2653.jpg' -> 'test/n02108089-boxer/n02108089_2653.jpg'
# renamed 'Images/n02108089-boxer/n02108089_3248.jpg' -> 'test/n02108089-boxer/n02108089_3248.jpg'
# renamed 'Images/n02108089-boxer/n02108089_8969.jpg' -> 'test/n02108089-boxer/n02108089_8969.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1159.jpg' -> 'test/n02108089-boxer/n02108089_1159.jpg'
# renamed 'Images/n02108089-boxer/n02108089_395.jpg' -> 'test/n02108089-boxer/n02108089_395.jpg'
# renamed 'Images/n02108089-boxer/n02108089_5753.jpg' -> 'test/n02108089-boxer/n02108089_5753.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1956.jpg' -> 'test/n02108089-boxer/n02108089_1956.jpg'
# renamed 'Images/n02087046-toy_terrier/n02087046_2279.jpg' -> 'test/n02087046-toy_terrier/n02087046_2279.jpg'
# ...

# %%
for i in dirlist:
  length=round(0.1*len(os.listdir('Images/'+i)))
  pathi='Images'
  # !find 'Images/$i' -type f -name "*.jpg" -print0 | xargs -0 shuf -e -n $length -z | xargs -0 mv -vt 'validation/$i'
# Out:
# renamed 'Images/n02108089-boxer/n02108089_15702.jpg' -> 'validation/n02108089-boxer/n02108089_15702.jpg'
# renamed 'Images/n02108089-boxer/n02108089_8739.jpg' -> 'validation/n02108089-boxer/n02108089_8739.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1690.jpg' -> 'validation/n02108089-boxer/n02108089_1690.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1757.jpg' -> 'validation/n02108089-boxer/n02108089_1757.jpg'
# renamed 'Images/n02108089-boxer/n02108089_2796.jpg' -> 'validation/n02108089-boxer/n02108089_2796.jpg'
# renamed 'Images/n02108089-boxer/n02108089_12827.jpg' -> 'validation/n02108089-boxer/n02108089_12827.jpg'
# renamed 'Images/n02108089-boxer/n02108089_1619.jpg' -> 'validation/n02108089-boxer/n02108089_1619.jpg'
# renamed 'Images/n02087046-toy_terrier/n02087046_4409.jpg' -> 'validation/n02087046-toy_terrier/n02087046_4409.jpg'
# renamed 'Images/n02087046-toy_terrier/n02087046_2419.jpg' -> 'validation/n02087046-toy_terrier/n02087046_2419.jpg'
# ...

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 120)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('train')
valid_files, valid_targets = load_dataset('validation')
test_files, test_targets = load_dataset('test')

# load list of dog names
dog_names = [item[17:-1] for item in sorted(glob("Images/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras

# %%
train_tensors = paths_to_tensor(train_files).astype('float32')/255
# Out:
# 100%|██████████| 10294/10294 [00:45<00:00, 227.55it/s]

# %%
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
# Out:
# 100%|██████████| 935/935 [00:08<00:00, 113.00it/s]

# %%
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 1045/1045 [00:10<00:00, 100.82it/s]

# %%
np.save(open('train_tensors.npy', 'wb'), train_tensors)

# %%
np.save(open('test_tensors.npy', 'wb'), test_tensors)
np.save(open('tvalid_tensors.npy', 'wb'), valid_tensors)

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
# model.add(Dense(250, activation='relu'))
# model.add(Dense(200, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(120, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 16)      0
# ...

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
epochs=2
checkpointer = ModelCheckpoint(filepath='weights/myarch.hdf5',verbose=1, save_best_only=True)
model.fit(train_tensors, train_targets,validation_data=(valid_tensors, valid_targets),epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 10294 samples, validate on 935 samples
# Epoch 1/4
# 10294/10294 [==============================] - 619s 60ms/step - loss: 4.7027 - acc: 0.0207 - val_loss: 4.4856 - val_acc: 0.0396
#
# Epoch 00001: val_loss improved from inf to 4.48562, saving model to weights/myarch.hdf5
# Epoch 2/4
# 10294/10294 [==============================] - 620s 60ms/step - loss: 4.2598 - acc: 0.0626 - val_loss: 4.2207 - val_acc: 0.0684
#
# Epoch 00002: val_loss improved from 4.48562 to 4.22067, saving model to weights/myarch.hdf5
# Epoch 3/4
# 10294/10294 [==============================] - 620s 60ms/step - loss: 3.5974 - acc: 0.1713 - val_loss: 4.4586 - val_acc: 0.0738
#
# Epoch 00003: val_loss did not improve from 4.22067
# Epoch 4/4
# ...

# %%
model.load_weights('weights/myarch.hdf5')

# %%
myarch_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]
test_accuracy = 100*np.sum(np.array(myarch_predictions)==np.argmax(test_targets, axis=1))/len(myarch_predictions)
print('Test accuracy: %f%%' % test_accuracy)
# Out:
# Test accuracy: 5.454545%

# %%
# trying inception pretrained on imagenet
from keras.applications.inception_v3 import InceptionV3
base_model = InceptionV3(weights='imagenet', include_top=False)
base_model.summary()
# Out:
# ...
# 87916544/87910968 [==============================] - 1s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
traininc=base_model.predict(train_tensors)
testvinc=base_model.predict(test_tensors)
validinc=base_model.predict(valid_tensors)

# %%
inc = Sequential()
inc.add(GlobalAveragePooling2D(input_shape=traininc.shape[1:]))
inc.add(Dense(300, activation='relu'))
inc.add(Dense(200, activation='relu'))
inc.add(Dense(120, activation='softmax'))

inc.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               614700
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dense_5 (Dense)              (None, 120)               24120
# ...
# Total params: 699,020
# Trainable params: 699,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
inc.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath='weights/inc.hdf5', 
                               verbose=1, save_best_only=True)

inc.fit(traininc, train_targets, 
          validation_data=(validinc, valid_targets),
          epochs=5, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 10294 samples, validate on 935 samples
# Epoch 1/5
# 10294/10294 [==============================] - 11s 1ms/step - loss: 1.5044 - acc: 0.6309 - val_loss: 1.0207 - val_acc: 0.7005
#
# Epoch 00001: val_loss improved from inf to 1.02066, saving model to weights/inc.hdf5
# Epoch 2/5
# 10294/10294 [==============================] - 8s 760us/step - loss: 0.8334 - acc: 0.7618 - val_loss: 1.1031 - val_acc: 0.7251
#
# Epoch 00002: val_loss did not improve from 1.02066
# Epoch 3/5
# 10294/10294 [==============================] - 8s 736us/step - loss: 0.7047 - acc: 0.7988 - val_loss: 0.9357 - val_acc: 0.7529
#
# Epoch 00003: val_loss improved from 1.02066 to 0.93572, saving model to weights/inc.hdf5
# Epoch 4/5
# 10294/10294 [==============================] - 8s 742us/step - loss: 0.6100 - acc: 0.8227 - val_loss: 1.0430 - val_acc: 0.7476
#
# Epoch 00004: val_loss did not improve from 0.93572
# Epoch 5/5
# ...

# %%
inc.load_weights('weights/inc.hdf5')

# %%
inc_predictions = [np.argmax(inc.predict(np.expand_dims(feature, axis=0))) for feature in testvinc]

test_accuracy = 100*np.sum(np.array(inc_predictions)==np.argmax(test_targets, axis=1))/len(inc_predictions)
print('Test accuracy: %f%%' % test_accuracy)
# Out:
# Test accuracy: 74.545455%

# %%
from keras.applications.vgg19 import VGG19
vggmodel=VGG19(weights='imagenet',include_top=False)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
import numpy as np
train_tensors1=np.load('train_tensors.npy')
trainvgg19=vggmodel.predict(train_tensors1)

# %%
test_tensors1=np.load('test_tensors.npy')

testvgg19=model.predict(test_tensors1)

# %%
valid_tensors1=np.load('valid_tensors.npy')
validvgg19=model.predict(valid_tensors1)

# %%
VGG19_model = Sequential()
VGG19_model.add(GlobalAveragePooling2D(input_shape=trainvgg19.shape[1:]))
VGG19_model.add(Dense(500, activation='relu'))
VGG19_model.add(Dense(300, activation='relu'))
VGG19_model.add(Dense(120, activation='softmax'))

VGG19_model.summary()

# %%
VGG19_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath='weights/weights.bestfinaleVGG19.hdf5', 
                               verbose=1, save_best_only=True)

VGG19_model.fit(trainvgg19, train_targets, 
          validation_data=(validvgg19, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)

# %%
VGG19_model.load_weights('weights/weights.bestfinaleVGG19.hdf5')

# %%
VGG19_predictions = [np.argmax(VGG19_model.predict(np.expand_dims(feature, axis=0))) for feature in testvgg19]

test_accuracy = 100*np.sum(np.array(VGG19_predictions)==np.argmax(test_targets, axis=1))/len(VGG19_predictions)
print('Test accuracy: %f%%' % test_accuracy)

# %%
def extract_InceptionV3(tensor):
	from keras.applications.inception_v3 import InceptionV3, preprocess_input
	return InceptionV3(weights='imagenet', include_top=False).predict(preprocess_input(tensor))

# %%
def predict_dog_breed(path):
    image2tensor = path_to_tensor(path)
    bottleneckfeatures = extract_InceptionV3(image2tensor)
    prediction = inc.predict(bottleneckfeatures)[0]
    breeds_predicted = [dog_names[idx] for idx in np.argsort(prediction)[::-1][:1]]
    return breeds_predicted

# %%
import matplotlib.image as mlibimg
import matplotlib.pyplot as plt

def dog_prediction(path):
    doggybreed= predict_dog_breed(path)
    img = mlibimg.imread(path)
    print('Predicted Dog Breed is: {}.'.format(doggybreed))
    imgplot = plt.imshow(img)

# %%
# !wget https://unsplash.com/photos/dO2WTawCTC4/download?force=true
# Out:
# --2019-04-23 04:35:17--  https://unsplash.com/photos/dO2WTawCTC4/download?force=true
# Resolving unsplash.com (unsplash.com)... 151.101.65.181, 151.101.1.181, 151.101.193.181, ...
# Connecting to unsplash.com (unsplash.com)|151.101.65.181|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://images.unsplash.com/photo-1553531384-411a247ccd73?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=boxed-water-is-better-1463986-unsplash.jpg [following]
# --2019-04-23 04:35:17--  https://images.unsplash.com/photo-1553531384-411a247ccd73?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=boxed-water-is-better-1463986-unsplash.jpg
# Resolving images.unsplash.com (images.unsplash.com)... 151.101.2.208, 151.101.66.208, 151.101.130.208, ...
# Connecting to images.unsplash.com (images.unsplash.com)|151.101.2.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3236781 (3.1M) [image/jpeg]
# Saving to: ‘download?force=true’
#
# ...

# %%
# !mv download?force=true dog1.jpg

# %%
# !wget https://unsplash.com/photos/K4mSJ7kc0As/download?force=true
# Out:
# --2019-04-23 04:37:37--  https://unsplash.com/photos/K4mSJ7kc0As/download?force=true
# Resolving unsplash.com (unsplash.com)... 151.101.65.181, 151.101.1.181, 151.101.193.181, ...
# Connecting to unsplash.com (unsplash.com)|151.101.65.181|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://images.unsplash.com/photo-1518020382113-a7e8fc38eac9?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=charles-550068-unsplash.jpg [following]
# --2019-04-23 04:37:37--  https://images.unsplash.com/photo-1518020382113-a7e8fc38eac9?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=charles-550068-unsplash.jpg
# Resolving images.unsplash.com (images.unsplash.com)... 151.101.2.208, 151.101.66.208, 151.101.130.208, ...
# Connecting to images.unsplash.com (images.unsplash.com)|151.101.2.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1794621 (1.7M) [image/jpeg]
# Saving to: ‘download?force=true’
#
# ...

# %%
# !mv download?force=true dog2.jpg

# %%
# Out:
# --2019-04-23 04:47:36--  https://unsplash.com/photos/ZRZSmK362Xw/download?force=true
# Resolving unsplash.com (unsplash.com)... 151.101.65.181, 151.101.1.181, 151.101.193.181, ...
# Connecting to unsplash.com (unsplash.com)|151.101.65.181|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://images.unsplash.com/photo-1497993950456-cdb57afd1cf1?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=ken-reid-290754-unsplash.jpg [following]
# --2019-04-23 04:47:36--  https://images.unsplash.com/photo-1497993950456-cdb57afd1cf1?ixlib=rb-1.2.1&q=85&fm=jpg&crop=entropy&cs=srgb&dl=ken-reid-290754-unsplash.jpg
# Resolving images.unsplash.com (images.unsplash.com)... 151.101.2.208, 151.101.66.208, 151.101.130.208, ...
# Connecting to images.unsplash.com (images.unsplash.com)|151.101.2.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788076 (3.6M) [image/jpeg]
# Saving to: ‘download?force=true’
#
# ...

# %%
# !mv download?force=true dog3.jpg

# %%
dog_prediction('dog1.jpg')
# Out:
# Predicted Dog Breed is: ['Siberian_husky'].

# %%
dog_prediction('dog2.jpg')
# Out:
# Predicted Dog Breed is: ['pug'].
